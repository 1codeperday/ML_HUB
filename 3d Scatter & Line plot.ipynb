# %% [markdown]
# # 3D Scatter Plot

# %% [raw]
# in order to enable the 3-D elements, we will be needing toolikts ,
#
# Syntax : from mpl_toolkits import mplot3d
#
# ax = plt.axes(projection='3d') : - this will enable matplotlib to understand that we are
#
# indeed working with a 3d plot.
#
# Now using this axes we can create 3d scatter plot, 3d line plot. egs.:-
#
# ax = plt.axes(projection='3d')
#
# ax.scatter(x,y,z)
#
# ax.plot3D(x,y,z)
#
# Even though this 3d plot, we cannot rotate it, we cannot handle it. we cannot view it in a 3D view, which is not cool.
#
# In order to set label we use  plt.axes.set_xlabel('x-axis'), plt.axes.set_ylabel('y-axis'), plt.axes.set_zlabel('z-axis').
#
# %matpoltlib inline means to show infact we we are setting the back end to show the output then and there.
#
# %matplotlib notebook means to show infact we we are setting the back end to show the output then and there. And in addition we will get extra options as scroll,zoom etc
#
# Sometime notebook wont work then use  it two times will fix this :-
#
# %matplotlib notebook
#
# %matplotlib notebook

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
# %matplotlib notebook

# %%
x = np.random.random(100)*100
y = np.random.random(100)*100
z = np.random.random(100)*100

# %%
plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.scatter(x,y,z)
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## 3d line graph

# %%
plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.plot3D(x,y,z)
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
